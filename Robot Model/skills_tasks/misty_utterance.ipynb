# %%
from mistyPy import Robot
from misty_ide_comm import IdeComm

comm = IdeComm()

def main():
    comm.send_message('starting')
    misty = Robot()

    #Your code here

    comm.shutdown()


if __name__ == "__main__":
    misty_ip = "192.168.0.101"
    misty = Robot(misty_ip)
    comm.start(main)
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 from mistyPy import Robot
# ----> 2 from misty_ide_comm import IdeComm
#       4 comm = IdeComm()
#       6 def main():
#
# ModuleNotFoundError: No module named 'misty_ide_comm'

# %%
from mistyPy import Robot

# Replace these with your actual Misty's IP and API key
misty_ip = "192.168.0.101"
misty = Robot(misty_ip)


def greeting():
    current_response = misty.MoveArm("both", 45, 100)
    greeting_message = "Hello! I am Misty, your friendly robot." # Should be modified in the future 
    
    # Speak the greeting message
    misty.speak(greeting_message)

# if __name__ == "__main__":
#     try:
#         greet()
#     except KeyboardInterrupt:
#         pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 # Replace these with your actual Misty's IP and API key
#       4 misty_ip = "192.168.0.101"
# ----> 5 misty = Robot(misty_ip)
#       8 def greeting():
#       9     current_response = misty.MoveArm("both", 45, 100)
#
# File /usr/local/lib/python3.11/site-packages/mistyPy/__init__.py:27, in Robot.__init__(self, ip)
#      23 self.face_recognition_instance = None
#      25 self.available_subscriptions = ["StringMessage","TimeOfFlight","FaceDetection","FaceRecognition","LocomotionCommand","HaltCommand","SelfState","WorldState"]
# ---> 27 self.populateImages()
#      28 self.populateAudio()
#      29 self.populateLearnedFaces()
#
# File /usr/local/lib/python3.11/site-packages/mistyPy/__init__.py:93, in Robot.populateImages(self)
#      91 resp = requests.get('http://'+self.ip+'/api/images')
# ...

# %%
#!/usr/bin/env python

import sys
import rospy
import random
import time

from robot_action.srv import StringSrv, StringSrvResponse
from robot_action.msg import RobotPoint, RobotActionRequest
from std_msgs.msg import Int8
from std_msgs.msg import String



pointPublisher = rospy.Publisher('robot_point', RobotPoint, queue_size = 10)
movePublisher = rospy.Publisher('robot_other', Int8, queue_size = 10)
grabPublisher  = rospy.Publisher('robot_grab', Int8, queue_size = 10)
pubUtterance = rospy.Publisher('robot_utterance', String, queue_size=10)

def send_point_message(two_pieces,p1,l1,n1,p2,l2,n2):
	message = RobotPoint()
	message.two_locs = two_pieces
	
	message.piece1 = p1
	message.loc1 = l1
	message.numb1 = n1

	message.piece2 = p2
	message.loc2 = l2
	message.numb2 = n2
	
	pointPublisher.publish(message)
	



def send_move_message(command):
	movePublisher.publish(command)
	
def send_grab_message(command):
	grabPublisher.publish(command)
	
#######################################################################################


def reinforcement_question_1():
	question = ["An LED seems like the right piece, can you explain to me what it does?",
			"Does the EL E DEE emit a light?",
			"What does an EL E DEE do?"]			  
	n =  random.randint(0, len(question)-1)
	utterance = question[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_2():
	question = ["Why did you choose to orient the LED like that?",
			"What direction should the EL E DEE be pointing from compared to the positive side of the battery?"]			  
	n =  random.randint(0, len(question)-1)
	utterance = question[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_3():
	peer = ["Ah cool, I see you added both a resistor and an LED, why did we add the resistor",
			"When we have an LED in the circuit, should we always have a resistor?",
			"How come we added a resistor to the circuit?"]			  
	n =  random.randint(0, len(peer)-1)
	utterance = peer[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_4(condition):
	peer = ["Is the resistor the piece that makes the music lower?",
			"I see a resistor in the circuit, how does it affect the circuit?"]			  
	tutor = ["Is the resistor the piece that makes the music lower?",
			"I see a resistor in the circuit, how does it affect the circuit?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_5(condition):
	peer = ["Can you explain to me what a motor does?",
			"The motor seems like a good idea, can you explain to me how it works?",
			"Interesting. In general, when should a motor be used?"]			  
	tutor = ["Can you explain to me what a motor does?",
			"The motor seems like a good idea, can you explain to me how it works?",
			"Interesting. In general, when should a motor be used?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_6(condition):
	peer = ["Nice idea with the switch. What happens when we turn it on?",
			"When should a switch be used?",
			"I see a switch! How does the switch work?"]			  
	tutor = ["Nice idea with the switch. What happens when you turn it on?",
			"When should a switch be used?",
			"I see a switch! How does the switch work?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_7(condition):
	peer = ["Good choice to add a button to the circuit. What happens if we press it?",
			"Can you explain to me what a button does?",
			"When should we use a button in a circuit?"]			  
	tutor = ["Good choice to add a button to the circuit. What happens if you press it?",
			"Can you explain to me what a button does?",
			"When should you use a button in a circuit?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_8(condition):
	peer = ["I like the speaker. How does it work?",
			"Is the speaker the piece that will play music?",
			"When should we add a speaker to the circuit?"]			  
	tutor = ["I like the speaker. How does it work?",
			"Is the speaker the piece that will play music?",
			"When should you add a speaker to the circuit?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_9(condition):
	peer = ["What is the difference between the speaker and the music circuit?",
			"What is the functionality of the music circuit?",
			"Music circuits are tricky.  Can you explain to me what it does?"]			  
	tutor = ["What is the difference between the speaker and the music circuit?",
			"What is the functionality of the music circuit?",
			"Music circuits are tricky. Can you explain to me what it does?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	

def reinforcement_question_10(condition):
	peer = ["Do we use the blue wires to connect pieces together?",
			"How do the blue wires affect the circuit?",
			"Why do we need to connect pieces together?"]			  
	tutor = ["Do you use the blue wires to connect pieces together?",
			"How do the blue wires affect the circuit?",
			"Why do you need to connect pieces together?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_11(condition):
	peer = ["How come you connected all the pieces together like that?",
			"I see that all the pieces are connected to form a circuit. Should we always do that?",
			"Why did you form a circuit out of all the pieces?"]			  
	tutor = ["How come you connected all the pieces together like that?",
			"I see that all the pieces are connected to form a circuit. Should you always do that?",
			"Why did you form a circuit out of all the pieces?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_12(condition):
	peer = ["I see that the positive signal of the music circuit is connected to the positive in the battery. How come?",
			"I see that the negative signal of the music circuit is connected to the negative in the battery. Should we always do that?",
			"Can you explain to me, how we power a music circuit?"]			  
	tutor = ["I see that the positive signal of the music circuit is connected to the positive in the battery. How come?",
			"I see that the negative signal of the music circuit is connected to the negative in the battery. Should you always do that?",
			"Can you explain to me, how you power a music circuit?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_13(condition):
	peer = ["I see that we connected the output port of the music circuit to the positive side of the battery. Why did you do that?",
			"Can you explain to me how we connect the output port of the music circuit",
			"What does the output port of the music circuit do?"]			  
	tutor = ["I see that you connected the output port of the music circuit to the positive side of the battery. Why did you do that?",
			"Can you explain to me how you connect the output port of the music circuit",
			"What does the output port of the music circuit do?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_14(condition):
	peer = ["What is the trigger port of the music circuit?",
			"What do we connect to the trigger port in the music circuit?"]	  
	tutor = ["What is the trigger port of the music circuit?",
			"What should you connect to the trigger port in the music circuit?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	

def reinforcement_question_15(condition):
	peer = ["What is the hold port of the music circuit?",
			"What do we connect to the hold port in the music circuit?"]  
	tutor = ["What is the hold port of the music circuit?",
			"What do you connect to the hold port in the music circuit?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_16(condition):
	peer = ["What happens if we press the button and turn on the switch?"]	  
	tutor = ["What happens if you press the button and turn on the switch?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_question_17(condition):
	peer = ["What happens if we press the button or turn on the switch?"]
	tutor = ["What happens if you press the button or turn on the switch?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)
	
#####################################################################################################

def reinforcement_good_1(condition):
	peer = ["Interesting, yes, an LED should emit a light",
			"Adding the LED was a good idea!",
			"The LED created a light in the circuit"]			  
	tutor = ["Interesting, yes, an LED will emit a light",
			"Adding the LED was a good idea!",
			"The LED created a light in the circuit"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_2(condition):
	peer = ["The LED seems to be pointing in the correct direction",
			"Yes, I agree that the battery positive port should be connected to the positive port of the LED"]		  
	tutor = ["The LED seems to be pointing in the correct direction",
			"Yes, I agree that the battery positive port should be connected to the positive port of the LED"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_3(condition):
	peer = ["Yes. We should always add a resistor when there is a LED in the circuit.",
			"I see both a resistor and an LED, I will remember that",
			"I have learned that a resistor should be added when there is an LED"]			  
	tutor = ["Yes. You should always add a resistor when there is a LED in the circuit.",
			"I see both a resistor and an LED, That is correct",
			"You have learned that a resistor should be added when there is an LED"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_4(condition):
	peer = ["The resistor lowers the music",
			"The resistor will do the job of lowering volume of the music in this circuit",
			"I can see that a resistor should be added when we want to lower the music"]			  
	tutor = ["The resistor lowers the music",
			"The resistor will do the job of lowering volume of the music in this circuit",
			"I can see you know that a resistor should be added when you want to lower the music"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_5(condition):
	peer = ["I see a motor in the circuit just like the task asked.",
			"Adding a motor was a good idea",
			"Yes, we needed to have the motor in the circuit."]			  
	tutor = ["I see a motor in the circuit just like the task asked.",
			"Adding a motor was a good idea",
			"Yes, you needed to have the motor in the circuit."]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_6(condition):
	peer = ["I agree that a switch was needed",
			"There is a switch just like the task asked.",
			"Now we can turn the circuit on and off using the switch"]			  
	tutor = ["I agree that a switch was needed",
			"There is a switch just like the task asked.",
			"Now you can turn the circuit on and off using the switch"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_7(condition):
	peer = ["Clicking the button will let us turn the circuit on and off",
			"Adding a button was a good idea"]		  
	tutor = ["Clicking the button will let you turn the circuit on and off",
			"Adding a button was a good idea"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_8(condition):
	peer = ["The speaker will play music in the circuit",
			"There is a speaker on the circuit just like the task asked"] 
	tutor = ["The speaker will play music in the circuit",
			"There is a speaker on the circuit just like the task asked"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_9(condition):
	peer = ["Good job on adding the music circuit, that is a hard piece",
			"Yea, having a music circuit is a good idea",
			"The music circuit will send a signal to the speaker to play music"]			  
	tutor = ["Good job on adding the music circuit, that is a hard piece",
			"Yea, Having a music circuit is a good idea",
			"The music circuit will send a signal to the speaker to play music"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	

def reinforcement_good_10(condition):
	peer = ["I like how we connected several of the pieces using wires",
			"The blue wires connect several of the pieces together",
			"Good job, The pieces can all send signals to each other when they are connected with the wires"]			  
	tutor = ["I like how you connected several of the pieces using wires",
			"The blue wires connect several of the pieces together",
			"Good job, The pieces can all send signals to each other when they are connected with the wires"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_11(condition):
	peer = ["Impressive, we built a complete circuit together",
			"Yay, I think we did a good job having all the pieces connected together to the battery",
			"It looks like we build a good circuit"]			  
	tutor = ["Impressive, you built a complete circuit",
			"Yay, I think you did a good job having all the pieces connected together to the battery",
			"It looks like you build a good circuit"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_12(condition):
	peer = ["The music circuit seems to be powered correctly",
			"Yay, the music circuits positive and negative ports are connected to the battery",
			"I like how we connected the music circuit"]			  
	tutor = ["The music circuit is powered correctly",
			"Yay, the music circuits positive and negative ports are connected to the battery",
			"I like how you connected the music circuit"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_13(condition):
	peer = ["Awesome, the music circuit can now send signals to play a rythm of a song",
			"We are doing a good job connecting the out port of the music circuit"]		  
	tutor = ["Awesome, the music circuit can now send signals to play a rythm of a song",
			"You are doing a good job connecting the out port of the music circuit"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_14(condition):
	peer = ["The trigger port of the music circuit it connected correctly",
			"Lets try spinning that motor, and see if it triggers the music circuit to start playing",
			"The motor on the trigger port was a good idea."]			  
	tutor = ["The trigger port of the music circuit it connected correctly",
			"Try spinning that motor, and see if it triggers the music circuit to start playing",
			"The motor on the trigger port was a good idea."]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	

def reinforcement_good_15(condition):
	peer = ["The hold port of the music circuit it connected correctly",
			"Lets try pressing the button, while its pressed it should play music",
			"The button on the hold port was a good idea."]			  
	tutor = ["The hold port of the music circuit it connected correctly",
			"Try pressing the button, while its pressed it should play music",
			"The button on the hold port was a good idea."]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_16(condition):
	peer = ["Lets press the button and turn on the switch to see what happens",
			"Yes, the switch and the button seem to be correct"]
	tutor = ["Press the button and turn on the switch to see what happens",
			"Yes, the switch and the button are correct"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def reinforcement_good_17(condition):
	peer = ["Lets press the button and turn on the switch to see what happens",
			"Yes, the switch and the button seem to be correct"]		  
	tutor = ["Press the button and turn on the switch to see what happens",
			"Yes, the switch and the button seem to be correct"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)
	
#######################################################################

def wrongPiece_point(condition, name, loc1, numb1):
	peer = ["I am not so sure about this " + name + " over here, should it be on the board?",
			"Let's take another look at the task. Do you think it needs this " + name,
			"This " + name + " over here might be useful in other moments, but I don't think its needed this time",
			"Over here we have a " + name + ".I dont think its needed right now."]			  
	tutor = ["I am not so sure about this piece over here, should it be on the board?",
			"Let's take another look at the task. Do you think it needs this " + name,
			"This " + name + " over here is useful in other moments, but its not needed this time",
			"Over here we have a " + name + ". It is not needed right now."]
			
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_point_message(0, name, loc1, numb1, "", "", 0)
	time.sleep(3)
	send_robot_utterance(utterance)
	
def wrongPiece_nopoint(condition, name):
	peer = ["I see we have added a " + name + ". Let's think about if it is needed for the current task",
			"Can you explain to me what a " + name + " does?. Do you think we need it for the current task?",
			"I am pretty sure the " + name + " should not be on the board for the task we are doing right now"]
	tutor = ["I see you have added a " + name + ". Let's think about if it is needed for the current task",
			"Can you explain to me what a " + name + "does?. Do you think we need it for the current task?",
			"I am pretty sure the " + name + " should not be on the board for the task we are doing right now"]
			
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_robot_utterance(utterance)

	
################################################################################
	
def help_utterance_1(condition):
	peer = ["An LED might be needed on the board",
			"Looks like we dont have an LED on the board yet, how do you feel about adding one?",
			"Adding an LED, will satisfy having something that gives us a light.",
			"An LED creates a little light when it is connected correctly",
			"The task is mentioning having something that creates a light. Do you think the LED might do that?"]			  
	tutor = ["An LED might be needed on the board",
			"Looks like you dont have an LED on the board yet, how do you feel about adding one?",
			"Adding an LED, will satisfy having something that gives you a light.",
			"An LED creates a little light when it is connected correctly",
			"The task is mentioning having something that creates a light. Do you think the LED might do that?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_2(condition):
	peer = ["We need to make sure we have the LED facing the correct direction. It does not seem to be right now",
			"The LED positive side should be connected via wires to the batteries positive side",
			"There is a little positive symbol on one of the LED sides. Lets try connecting that to the positive side of the battery using wires"]			  
	tutor = ["You need to make sure you have the LED facing the correct direction. It does not seem to be right now",
			"The LED positive side should be connected via wires to the batteries positive side",
			"There is a little positive symbol on one of the LED sides. Try connecting that to the positive side of the battery using wires"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_3(condition):
	peer = ["The LED can not take all the current passing through it, so we must add a resistor to lower it.",
			"I have learned that anytime we add an LED to the board, we must also add something that lowers the amount of current going through.",
			"Because we have added an LED, we should also add a resistor."]			  
	tutor = ["The LED can not take all the current passing through it, so you must add a resistor to lower it.",
			"Anytime you add an LED to the board, you must also add something that lowers the amount of current going through.",
			"Because you have added an LED, you should also add a resistor."]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_4(condition):
	peer = ["The task wants us to play low music. The resistor lowers the amount of current passing through the circuit",
			"So we need to play low music. What piece do you think could lower the music?",
			"We need to add a resistor. It would lower the music."]			  
	tutor = ["The task wants you to play low music. The resistor lowers the amount of current passing through the circuit",
			"So you need to play low music. What piece do you think could lower the music?",
			"You need to add a resistor. It would lower the music."]	
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_5(condition):
	peer = ["So the task requires a motor. The only piece that looks like a motor is the yellow one with the spinny thing on top.",
			"We need to add the motor to the circuit",
			"It looks like the task wants a motor, lets try adding it to the circuit."]			  
	tutor = ["So the task requires a motor. The only piece that looks like a motor is the yellow one with the spinny thing on top.",
			"You need to add the motor to the circuit",
			"It looks like the task wants a motor, try adding it to the circuit."]	
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_6(condition):
	peer = ["So we need to turn the circuit on and off. How about using the switch?",
			"Lets try adding the switch to the circuit",
			"How about the switch? It would turn the circuit on and off."]			  
	tutor = ["So you need to turn the circuit on and off. How about using the switch?",
			"Try adding the switch to the circuit",
			"How about the switch? It would turn the circuit on and off."]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_7(condition):
	peer = ["So we need to turn the circuit on by pressing the button. Lets add the button?",
			"Lets try adding the button to the circuit",
			"How about the button? It would turn the circuit on when we press on it."]			  
	tutor = ["So you need to turn the circuit on by pressing the button. Add the button?",
			"Try adding the button to the circuit",
			"How about the button? It would turn the circuit on when you press on it."]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_8(condition):
	peer = ["We need a piece that can play some music. How about the speaker?",
			"The speaker can play music. Lets add it to the circuit.",
			"Can we try adding the red speaker to the circuit?"]			  
	tutor = ["You need a piece that can play some music. How about the speaker?",
			"The speaker can play music. Add it to the circuit.",
			"Can you try adding the red speaker to the circuit?"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_9(condition):
	# ~ peer = ["So the speaker will play the music. But we need something that creates the sound waves. The music circuit can do that",
			# ~ "I think the music circuit could create a song that the speaker plays",
			# ~ "I have learned that music circuits create the sound waves for a song. How about we add it?"]			  
	# ~ tutor = ["So the speaker will play the music. But you need something that creates the sound waves. The music circuit can do that",
			# ~ "The music circuit creates a song that the speaker plays",
			# ~ "Music circuits create the sound waves for a song. How about you add it?"]	
	peer = ["The music circuit will create the song for the speaker to play",
			"Lets try adding the music circuit to the board. It will create the song waves",
			"We still need to add a music circuit to the board."]
	tutor = ["The music circuit will create the song for the speaker to play",
			"Try adding the music circuit to the board. It will create the song waves",
			"You still need to add a music circuit to the board"]		
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	

def help_utterance_10(condition):
	# ~ peer = ["We have several pieces on the board. But they aren't connect to each other. Can we try connecting them together using the blue wires",
			# ~ "We can connect pieces together using the blue wires. They snap to each other at the ends.",
			# ~ "The pieces need to be connected to each other and to the battery."]			  
	# ~ tutor = ["You have several pieces on the board. But they aren't connect to each other. Can you try connecting them together using the blue wires",
			# ~ "You can connect pieces together using the blue wires. They snap to each other at the ends.",
			# ~ "The pieces need to be connected to each other and to the battery."]
	peer = ["Some of the pieces on the board aren't connected to each other. Can we try connecting them together using the blue wires",
			"We can connect pieces together using the blue wires. They snap to each other at the ends.",
			"The pieces need to be connected to each other and to the battery."]			  
	tutor = ["Some of the pieces on the board aren't connected to each other. Can you try connecting them together using the blue wires",
			"You can connect pieces together using the blue wires. They snap to each other at the ends.",
			"The pieces need to be connected to each other and to the battery."]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_11(condition):
	# ~ peer = ["For a circuit to work, all the pieces need to be connected together to form a loop. And the battery needs to be part of the loop",
			# ~ "There are pieces that are not connected to the battery. We need to connect all the pieces together such that they form a loop with the battery included in the loop.",
			# ~ "Using the blue wires, we should connect all the pieces together in a circle, and at the end of the circle we should have the battery."]			  
	# ~ tutor = ["For a circuit to work, all the pieces need to be connected together to form a loop. And the battery needs to be part of the loop",
			# ~ "There are pieces that are not connected to the battery. You need to connect all the pieces together such that they form a loop with the battery included in the loop.",
			# ~ "Using the blue wires, you should connect all the pieces together in a circle, and at the end of the circle you should have the battery."]
			
	peer = ["Lets make sure all the pieces are connected together in a loop. The battery needs to be part of the loop",
			"Some pieces are not connected to the battery. Lets connect them all together using wires",
			"Using the blue wires, we should connect all the pieces together in a circle, and at the end of the circle we should have the battery."]			  
	tutor = ["Make sure all the pieces are connected together in a loop. The battery needs to be part of the loop",
			"Some pieces are not connected to the battery. Connect them all together using wires",
			"Using the blue wires, you should connect all the pieces together in a circle, and at the end of the circle you should have the battery."]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_12(condition):
	# ~ peer = ["The music circuit has 4 different ports. To power it we need to make sure that the positive port is connected to the positive on the battery. \
	# ~ And that the negative port is connected to the negative on the battery.",
			# ~ "The music circuit does not seem to be powered correctly. Lets use blue wires to connect the positive to the positive on the battery, and the negative to the negative on the battery.",
			# ~ "Oh no. The music circuit does not have any power. It needs to be connected to the battery. Lets connect the positives and the negatives of each together using the wires."]			  
	# ~ tutor = ["The music circuit has 4 different ports. To power it you need to make sure that the positive port is connected to the positive on the battery. \
	# ~ And that the negative port is connected to the negative on the battery.",
			# ~ "The music circuit does not seem to be powered correctly. Use blue wires to connect the positive to the positive on the battery, and the negative to the negative on the battery.",
			# ~ "Oh no. The music circuit does not have any power. It needs to be connected to the battery. Connect the positives and the negatives of each together using the wires."]
			
	peer = ["To power the music circuit we need to make sure that its positive port is connected to the positive port of the battery.",
			"Connect the negative port of the music circuit to the negative port of the battery",
			"Lets connect the positives and the negatives of the music circuit and the battery together using wires"]
	tutor = ["To power the music circuit you need to make sure that its positive port is connected to the positive port of the battery.",
			"Connect the negative port of the music circuit to the negative port of the battery",
			"Connect the positives and the negatives of the music circuit and the battery together using wires"]

	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_13(condition):
	# ~ peer = ["The music circuit creates the song that the speaker should play. Now we need to connect them together. \
	# ~ The signal port of the music circuit should be connected to the positive side of the battery with a speaker in between",
			# ~ "Lets connect the music circuit to the speaker and the battery. Lets connect the bottom right side of the music circuit to the speaker, \
			 # ~ and connect the other side of the speaker to the battery."] 
	# ~ tutor = ["The music circuit creates the song that the speaker should play. \
	# ~ Now you need to connect them together. The signal port of the music circuit should be connected to the positive side of the battery with a speaker in between",
			# ~ "Connect the music circuit to the speaker and the battery. Connect the bottom right side of the music circuit to the speaker, \
			 # ~ and connect the other side of the speaker to the battery."]
	peer = ["Connect the speaker to the output port of the music circuit, and the other end of the speaker to the battery",
			"The speaker should be in betwween the outport port of the music circuit and the positive side of the battery",
			"Using wires, connect the speaker to the output port of the battery",
			"Using wires, connect one side of the speaker to the positive side of the battery"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_14(condition):
	peer = ["We need to connect the motor to the trigger input of the music circuit.",
			"If the motor is connect to the trigger input of the music circuit, spinning the motor will start the music",
			"Lets add a motor between the trigger of the music circuit and the positive side of the battery"]
	peer = ["You need to connect the motor to the trigger input of the music circuit.",
			"If the motor is connect to the trigger input of the music circuit, spinning the motor will start the music",
			"Add a motor between the trigger of the music circuit and the positive side of the battery"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	

def help_utterance_15(condition):
	# ~ peer = ["While we hold down the button, the music needs to play. Therefore I think we need a the button on the hold port of the music circuit. \
	# ~ And lets not forget to connect the button to the battery via wires.",
			# ~ "So I think we need a connection going from the positive side of the battery to the motor. And then we need to connect the motor to the hold input of the music circuit"]		  
	# ~ tutor = ["While you hold down the button, the music needs to play. Therefore you need a the button on the hold port of the music circuit. \
	# ~ And dont forget to connect the button to the battery via wires.",
			# ~ "You will need a connection going from the positive side of the battery to the motor. And then you need to connect the motor to the hold input of the music circuit"]
	peer = ["While we are holding down the button, the music needs to play.",
			"Lets add the button to the hold port of the music circuit, the other side of the button we can connect to the battery"
			"Lets have a button in between the hold port of the music circuit and the positive side of the battery"]
	tutor = ["While you are holding down the button, the music needs to play.",
			"Add the button to the hold port of the music circuit, the other side of the button you can connect to the battery"
			"Have a button in between the hold port of the music circuit and the positive side of the battery"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_16(condition): #AND
	# ~ peer = ["I think we need both the button pressed and the switch turned on so current can pass through. If we connect them both together directly, then current will \
	# ~ only pass through if we turn both on.",
			# ~ "First off, we should need to have both a switch and a button on the board. They should be connected in sequence so that the circuit only is powered when both are turned on."]		  
	# ~ tutor = ["You need both the button to be pressed and the switch turned on so current can pass through. If you connect them both together directly, then current will \
	# ~ only pass through if we turn both on.",
			# ~ "First off, you should have both a switch and a button on the board. They should be connected in sequence so that the circuit only is powered when both are turned on."]
			
	peer = ["For this task the circuit will only work when both the button is pressed and the switch is on",
			"There should be a button and switch in the main loop of the circuit",
			"For this task, lets have a button and a switch connected together"]
	tutor = ["For this task the circuit will only work when both the button is pressed and the switch is on",
			"There should be a button and switch in the main loop of the circuit",
			"For this task, have a button and a switch connected together"]

	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_utterance_17(condition): #OR
	# ~ peer = ["So either the switch needs to be turned on or the button needs to be pressed. So they need to be connected in parallel. Which means that we need to create a split with the wires, have the \
	# ~ switch and the button on the splits, and then bring them back together.",
			# ~ "This is a tricky one. We need to create a split with a switch on one side of the split, and the button on the other side of the split. With a wire comming out of the \
			# ~ battery, lets try to split that wire into two different ones and connect a switch and a button to each side of the split. After that we can connect the button and the \
			# ~ switch together again using a wire that will power the rest of the circuit."]			  
	# ~ tutor = ["So either the switch needs to be turned on or the button needs to be pressed. So they need to be connected in parallel. Which means that you need to create a split with the wires, have the \
	# ~ switch and the button on the splits, and then bring them back together.",
			# ~ "This is a tricky one. You need to create a split with a switch on one side of the split, and the button on the other side of the split. With a wire comming out of the \
			# ~ battery, try to split that wire into two different ones and connect a switch and a button to each side of the split. After that you can connect the button and the \
			# ~ switch together again using a wire that will power the rest of the circuit."]
			
	peer = ["In this task either the button needs to be pressed, or, the switch needs to be turned on for the circuit to work",
			"For this one, we need to split one of the wires, into two wires, and connect the button and the switch to each end. Afterwards you can bring the wires together again",
			"One way to do this, is to connect both the ends of switch and the button together using wires. That way as long as one is pressed, current can pass through",
			"Lets place the switch and button side by side, and connect them using wires at both ends. Now connect each end to the positive and negative sides of the battery"]
	tutor = ["In this task either the button needs to be pressed, or, the switch needs to be turned on for the circuit to work",
			"For this one, you need to split one of the wires, into two wires, and connect the button and the switch to each end. Afterwards you can bring the wires together again",
			"One way to do this, is to connect both the ends of switch and the button together using wires. That way as long as one is pressed, current can pass through",
			"Lets place the switch and button side by side, and connect them using wires at both ends. Now connect each end to the positive and negative sides of the battery"]
	
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)
	
################################################################################


def help_movement_1(condition):
	peer = ["Here, lets try to add the LED to the circuit",
			"How about adding this LED to the circuit to create the light",
			"This LED is needed on the board"]			  
	tutor = ["Here, try to add the LED to the circuit",
			"How about adding this LED to the circuit to create the light",
			"This LED is needed on the board"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_grab_message(1)
	send_robot_utterance(utterance)	
	
	
	
def help_movement_2(condition, letter_led, number_led):

	if (condition == "peer"):
		send_point_message(1, "led", letter_led, number_led,"battery", "C", 8) #two_pieces,p1,l1,n1,p2,l2,n2):
		send_robot_utterance("We want to have the positive side of the battery connected to the positive side of the LED")
		send_robot_utterance("And we want to have the negative side of the battery connected to the negative side of the LED")
	else:
		send_point_message(1, "led", letter_led, number_led,"battery", "C", 8)
		send_robot_utterance("You want to have the positive side of the battery connected to the positive side of the LED")
		send_robot_utterance("And you want to have the negative side of the battery connected to the negative side of the LED")


def help_movement_3(condition):
	peer = ["Here, lets try to add the resistor to the circuit",
			"Whenever there is an LED, we also need a resistor",
			"This resistor is needed on the board"]			  
	tutor = ["Here, try to add the resistor to the circuit",
			"Whenever there is an LED, you also need a resistor",
			"This resistor is needed on the board"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_grab_message(4)
	send_robot_utterance(utterance)	
	
def help_movement_4(condition):
	peer = ["Here, lets try to add the resistor to the circuit",
			"How about adding this resistor to the circuit as it will make the music play softer",
			"This resistor is needed on the board"]			  
	tutor = ["Here, try to add the resistor to the circuit",
			"How about adding this resistor to the circuit as it will make the music play softer",
			"This resistor is needed on the board"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_grab_message(4)
	send_robot_utterance(utterance)	
	
def help_movement_5(condition):
	peer = ["Here, lets try to add the motor to the circuit",
			"How about adding this motor to the circuit as the task is asking for a motor",
			"This motor is needed on the board"]			  
	tutor = ["Here, try to add the motor to the circuit",
			"How about adding this motor to the circuit as the task is asking for a motor",
			"This motor is needed on the board"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_grab_message(5)
	send_robot_utterance(utterance)	
	
def help_movement_6(condition):
	peer = ["Here, lets try to add the switch to the circuit",
			"How about adding this switch to the circuit so we can turn it off and on",
			"This switch is needed on the board"]			  
	tutor = ["Here, try to add the switch to the circuit",
			"How about adding this switch to the circuit so you can turn it off and on",
			"This switch is needed on the board"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_grab_message(6)
	send_robot_utterance(utterance)	
	
def help_movement_7(condition):
	peer = ["Here, lets try to add the button to the circuit",
			"How about adding this button to the circuit so the circuit is on while we are pressing it",
			"This button is needed on the board"]			  
	tutor = ["Here, try to add the button to the circuit",
			"How about adding this button to the circuit so the circuit is on while you are pressing it",
			"This button is needed on the board"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_grab_message(7)
	send_robot_utterance(utterance)	
	
def help_movement_8(condition):
	peer = ["Here, lets try to add the speaker to the circuit",
			"How about adding this speaker to the circuit as it can play us some music",
			"This speaker is needed on the board"]			  
	tutor = ["Here, try to add the speaker to the circuit",
			"How about adding this speaker to the circuit  as it can play you some music",
			"This speaker is needed on the board"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_grab_message(8)
	send_robot_utterance(utterance)	
	
def help_movement_9(condition):
	peer = ["Here, lets try to add the music circuit to the circuit",
			"How about adding this music circuit to the circuit and it can send a song for the speaker to play",
			"This music circuit is needed on the board"]			  
	tutor = ["Here, try to add the music circuit to the circuit",
			"How about adding this music circuit to the circuit and it can send a song for the speaker to play",
			"This music circuit is needed on the board"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_grab_message(9)
	send_robot_utterance(utterance)	

def help_movement_10(condition, p1, l1, n1, p2, l2, n2):
	peer = ["We have several pieces on the board. But they aren't connect to each other. Can we try connecting them together using the blue wires",
			"We can connect pieces together using the blue wires. They snap to each other at the ends.",
			"The pieces need to be connected to each other and to the battery."]			  
	tutor = ["You have several pieces on the board. But they aren't connect to each other. Can you try connecting them together using the blue wires",
			"You can connect pieces together using the blue wires. They snap to each other at the ends.",
			"The pieces need to be connected to each other and to the battery."]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	
	send_point_message(1,p1, l1, n1, p2, l2, n2)
	send_robot_utterance(utterance)	
	
def help_movement_11(condition):
	peer = ["For a circuit to work, all the pieces need to be connected together to form a loop like this. And the battery needs to be part of the loop",
			"We need to connect all the pieces together in a circle such that they form a loop with the battery included in the loop.",
			"Using the blue wires, we should connect all the pieces together in a circle, and at the end of the circle we should have the battery."]			  
	tutor = ["For a circuit to work, all the pieces need to be connected together to form a loop like this. And the battery needs to be part of the loop",
			"You need to connect all the pieces together in a circle such that they form a loop with the battery included in the loop.",
			"Using the blue wires, you should connect all the pieces together in a circle, and at the end of the circle you should have the battery."]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_move_message(2)
	time.sleep(5)
	send_robot_utterance(utterance)	
	
def help_movement_12(condition, letter_mc, number_mc):
	# ~ peer = ["The music circuit has 5 different ports. To power it we need to make sure that the positive port is connected to the positive on the battery. \
	# ~ And that the negative port is connected to the negative on the battery.",
			# ~ "The music circuit does not seem to be powered correctly. Lets use blue wires to connect the positive to the positive on the battery, and the negative to the negative on the battery.",
			# ~ "Oh no. The music circuit does not have any power. It needs to be connected to the battery. Lets connect the positives and the negatives of each together using the wires."]			  
	# ~ tutor = ["The music circuit has 5 different ports. To power it you need to make sure that the positive port is connected to the positive on the battery. \
	# ~ And that the negative port is connected to the negative on the battery.",
			# ~ "The music circuit does not seem to be powered correctly. Use blue wires to connect the positive to the positive on the battery, and the negative to the negative on the battery.",
			# ~ "Oh no. The music circuit does not have any power. It needs to be connected to the battery. Connect the positives and the negatives of each together using the wires."]
	peer = ["To power the music circuit, lets connect its positive to the positive on the battery, and its negative to the negative on the battery",
			"The music circuit does not have power. Lets connect the positives and the negatives of the music circuit to the battery",
			"For the music circuit to work, the positive of the music circuit should be connected to the positive of the battery",
			"For the music circuit to work, the negative of the music circuit should be connected to the negative of the battery"]
	tutor = ["To power the music circuit, connect its positive to the positive on the battery, and its negative to the negative on the battery",
			"The music circuit does not have power. Connect the positives and the negatives of the music circuit to the battery",
			"For the music circuit to work, the positive of the music circuit should be connected to the positive of the battery",
			"For the music circuit to work, the negative of the music circuit should be connected to the negative of the battery"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
	send_robot_utterance(utterance)	
	
def help_movement_13(condition, letter_mc, number_mc):
	# ~ n =  random.randint(0, len(peer)-1)
	# ~ if (n == 0 and condition == "peer"):
		# ~ send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
		# ~ send_robot_utterance("The music circuit creates the song that the speaker should play. Now we need to connect them together.")
		# ~ send_robot_utterance("The out port of the music circuit should be connected to the positive side of the battery with a speaker in between")
	# ~ if (n == 1 and condition == "peer"):
		# ~ send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
		# ~ send_robot_utterance("Lets connect the music circuit to the speaker and the battery. Lets connect the bottom right side of the music circuit to the speaker")
		# ~ send_robot_utterance("And lets connect the other side of the speaker to the battery. There can be wires and other pieces in between.")
	# ~ if (n == 0 and condition == "tutor"):
		# ~ send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
		# ~ send_robot_utterance("The music circuit creates the song that the speaker should play.")
		# ~ send_robot_utterance("Now you need to connect them together. The out port of the music circuit should be connected to the positive side of the battery with a speaker in between")
	# ~ if (n == 1 and condition == "tutor"):	
		# ~ send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
		# ~ send_robot_utterance("Connect the music circuit to the speaker and the battery. Connect the bottom right side of the music circuit to the speaker")
		# ~ send_robot_utterance("And lets connect the other side of the speaker to the battery. There can be wires and other pieces in between.")
		
	# ~ peer = ["The music circuit creates the song that the speaker should play. Now we need to connect them together. \
	# ~ The out port of the music circuit should be connected to the positive side of the battery with a speaker in between",
			# ~ "Lets connect the music circuit to the speaker and the battery. Lets connect the bottom right side of the music circuit to the speaker, \
			 # ~ and connect the other side of the speaker to the battery. There can be wires and other pieces in between."] 
	# ~ tutor = ["The music circuit creates the song that the speaker should play. \
	# ~ Now you need to connect them together. The out port of the music circuit should be connected to the positive side of the battery with a speaker in between",
			# ~ "Connect the music circuit to the speaker and the battery. Connect the bottom right side of the music circuit to the speaker, \
			 # ~ and connect the other side of the speaker to the battery. There can be wires and other pieces in between."]
	peer = ["For the speaker to work it should be connected on one side to the positive of the battery and the other side to the out port of the music circuit",
			"Lets have the speaker in between the positive side of the battery and the out port of the music circuit",
			"The speaker plays the music that the music circuit created. Lets connect the speaker to the out port of the music circuit"]
	tutor = ["For the speaker to work it should be connected on one side to the positive of the battery and the other side to the out port of the music circuit",
			"You should have the speaker in between the positive side of the battery and the out port of the music circuit",
			"The speaker plays the music that the music circuit created. Connect the speaker to the out port of the music circuit"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
	send_robot_utterance(utterance)	
	
def help_movement_14(condition, letter_mc, number_mc):
	
	# ~ if (condition == "peer"):
		# ~ send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
		# ~ send_robot_utterance("The motor spinning should start the circuit. Therefore we should have the motor between the trigger input of the music circuit and the battery.")
		# ~ send_robot_utterance("Lets connect one side of the motor to the battery using wires and connect the other side to where it says trigger on the music circuit")
	# ~ if (condition == "tutor"):
		# ~ send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
		# ~ send_robot_utterance("The motor spinning should start the circuit. Therefore you should have the motor between the trigger input of the music circuit and the battery.")
		# ~ send_robot_utterance("Connect one side of the motor to the battery using wires and connect the other side to where it says trigger on the music circuit")
		
	# ~ peer = ["The motor spinning should start the circuit. Therefore we need to connect the motor to the trigger input of the music circuit. And then connect the other side of the motor to the battery",
			# ~ "If we have a long wire going from the battery to the music circuit, we can connect both the trigger input and the positive input \
			# ~ of the music circuit to the wire. We also need to have a motor in between the wire and the music circuit trigger."]			  
	# ~ tutor = ["The motor spinning should start the circuit. Therefore you need to connect the motor to the trigger input of the music circuit. And then connect the other side of the motor to the battery",
			# ~ "If you have a long wire going from the battery to the music circuit, you can connect both the trigger input and the positive input \
			# ~ of the music circuit to the wire. You also need to have a motor in between the wire and the music circuit trigger."]
	peer = ["When you use your finger to spin the motor, the speaker should start playing music",
			"The motor should be connected to the trigger port of the music circuit",
			"Lets connect one side of the motor to the positive side of the battery, and the other side to the trigger port of the music circuit"]
	tutor = ["When you use your finger to spin the motor, the speaker should start playing music",
			"The motor should be connected to the trigger port of the music circuit",
			"Connect one side of the motor to the positive side of the battery, and the other side to the trigger port of the music circuit"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
	send_robot_utterance(utterance)	

def help_movement_15(condition, letter_mc, number_mc):
	
	# ~ if (condition == "peer"):
		# ~ send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
		# ~ send_robot_utterance("While we hold down the button, the music needs to play. Therefore I think we need the button on the hold port of the music circuit.")
		# ~ send_robot_utterance("And lets not forget to connect the button to the positive side of the battery via wires.")
	# ~ if (condition == "tutor"):
		# ~ send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
		# ~ send_robot_utterance("While we hold down the button, the music needs to play. Therefore I think we need the button on the hold port of the music circuit.")
		# ~ send_robot_utterance("And do not forget to connect the button to the positive side of the battery via wires.")
		
	# ~ peer = ["While we hold down the button, the music needs to play. Therefore I think we need the button on the hold port of the music circuit. \
	# ~ And lets not forget to connect the button to the battery via wires.",
			# ~ "So I think we need a connection going from the positive side of the battery to the button. And then we need to connect the button to the hold input of the music circuit"]		  
	# ~ tutor = ["While you hold down the button, the music needs to play. Therefore you need a the button on the hold port of the music circuit. \
	# ~ And dont forget to connect the button to the battery via wires.",
			# ~ "You will need a connection going from the positive side of the battery to the button. And then you need to connect the button to the hold input of the music circuit"]
	peer = ["While we are holding the button down, the music should play. When we let it go it should stop.",
			"The button should be placed on the hold port of the music circuit",
			"Lets have the button between the positive side of the battery and the hold port of the music circuit"]
	tutor = ["While you are holding the button down, the music should play. When you let it go it should stop.",
			"The button should be placed on the hold port of the music circuit",
			"You should have the button between the positive side of the battery and the hold port of the music circuit"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
		
	send_point_message(1, "mc", letter_mc, number_mc,"battery", "C", 8)
	send_robot_utterance(utterance)	
	
def help_movement_16(condition):
	# ~ peer = ["I think we need the button pressed and the switch turned on so current can pass through. If we connect them both together directly, then current will \
	# ~ only pass through if we turn both on.",
			# ~ "First off, we should need to have both a switch and a button on the board. They should be connected in sequence so that the circuit only is powered when both are turned on."]		  
	# ~ tutor = ["You need the button pressed and the switch turned on so current can pass through. If you connect them both together directly, then current will \
	# ~ only pass through if we turn both on.",
			# ~ "First off, you should have both a switch and a button on the board. They should be connected in sequence so that the circuit only is powered when both are turned on."]
	peer = ["The circuit should only work if the button is pressed and the switch is turned on",
			"Lets connect the switch and button together in the loop of the circuit",
			"We should connect the end of the switch to one end of the button in this circuit"]
	tutor = ["The circuit should only work if the button is pressed and the switch is turned on",
			"Connect the switch and button together in the loop of the circuit",
			"You should connect the end of the switch to one end of the button in this circuit"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def help_movement_17(condition):
	# ~ peer = ["So either the switch need to be turned on or the button needs to be pressed. So they need to be connected in parallel. Which means that we need to create a split with the wires, have the \
	# ~ switch and the button on the splits, and then bring them back together.",
			# ~ "This is a tricky one. We need to split a wire into two separate wires and then connect a switch to one end, and the button to the other end. Afterwards we need to bring \
			# ~ the wires back together and connect the remaining pieces to it and to the battery."]			  
	# ~ tutor = ["So either the switch should be turned on or the button needs to be pressed. So they need to be connected in parallel. Which means that you need to create a split with the wires, have the \
	# ~ switch and the button on the splits, and then bring them back together.",
			# ~ "This is a tricky one. You need to split a wire into two separate wires and then connect a switch to one end, and the button to the other end. Afterwards you need to bring \
			# ~ the wires back together and connect the remaining pieces to it and to the battery."]	
	peer = ["In this task the circuit should work if either the button is pressed or the switch is on",
			"To create the or behavior, we should split a wire in two, and connect the button and switch to each end, and then bring them together using wires",
			"Lets try placing the button and switch side by side, and connecting their ends together. Then we can connect them to the battery and the rest of the circuit"]
	tutor = ["In this task the circuit should work if either the button is pressed or the switch is on",
			"To create the or behavior, you should split a wire in two, and connect the button and switch to each end, and then bring them together using wires",
			"Try placing the button and switch side by side, and connecting their ends together. Then you can connect them to the battery and the rest of the circuit"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)
	


















	
#######################################################################

#robot utterances for start of task
# ~ def next_task(task_question):
	# ~ peer = "So our task is: " + task_question
	# ~ tutor= "So your taks is: " + task_question
	# ~ if (condition == "peer"):
		# ~ utterance = peer
	# ~ else:
		# ~ utterance = tutor
	# ~ send_robot_utterance(utterance)	
	
def start(condition):
	send_move_message(3)
	peer = ["Hmmm, lets see what we need to do for our next task",
			"Looks like we have the next task, we can do this!",
			"Next task is up!",
			"We have our next task",
			"Let's see what we need to do next"]
				  
	tutor = ["Hmmm, lets see what you need to do for your next task",
			"Looks like you have the next task, you can do this!",
			"Next task is up!",
			"You have your next task",
			"Let's see what you need to do next"]
	n =  random.randint(0, len(peer)-1)
	look_t = random.randint(0,3)
	# ~ time.sleep(3)
	if (look_t == 0):
		send_move_message(1)
		time.sleep(5)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
		

#robot utterances for end of task - correct
def finished_correct(condition):
	send_move_message(3)
	peer = ["Yay, we did a great job. Lets clear up the board for the next task",
				  "Awesome, looks like we did that perfectly. Can you help me removing the pieces back onto the styrofoam?",
				  "Nice, we did the task just like it was meant. Lets clear up the pieces",
				  "Yay, go us. Can you take each piece and put it back onto the styrofoam?",
				  "Awesome, we make a good team"]
				  
	tutor = ["Yay, you did a great job. Clear up the board for the next task",
				  "Awesome, looks like you did that perfectly. COuld you remove the pieces back onto the styrofoam?",
				  "Nice, you did the task just like it was meant. Clear up the pieces",
				  "Yay, go you!Can you take each piece and put it back onto the styrofoam?",
				  "Awesome, you are a good student"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
			  
#robot utterances for end of task - incorrect
def finished_incorrect(condition):
	send_move_message(3)
	peer = ["Oh no, we were not able to finish it correctly in time. Lets clear up the board for the next one",
				  "We ran out of time. So we did not do this one, but hopefully we can do the next one",
				  "Times up. That was a hard one, hopefully the next one is easier. Please help me remove all the pieces back on to the styrofoam.",
				  "Looks like we did that wrong and that we ran out of time"]
				  
	tutor = ["Oh no, you were not able to finish it correctly in time. Clear up the board for the next one",
				  "You ran out of time. So you did not do this one, but hopefully you can do the next one",
				  "Times up. That was a hard one, hopefully the next one is easier. Please remove all the pieces back on to the styrofoam.",
				  "Looks like you did that wrong and that you ran out of time"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def notfinished_incorrect(condition):
	peer = ["It looks like there still is a mistake that we need to fix",
				  "We are not doing what the task asks",
				  "There are still some mistakes",
				  "Let's look at what the task is asking again",
				  "I dont think we are done yet",
				  "It's not fully working yet",
				  "Let's continue trying a bit more"]
				  
	tutor = ["It looks like there still is a mistake that you need to fix",
				  "You are not doing what the task asks",
				  "There are still some mistakes",
				  "Look at what the task is asking again",
				  "I dont think you are done yet",
				  "It's not fully working yet",
				  "Continue trying a bit more"]
	n =  random.randint(0, len(peer)-1)
	if (condition == "peer"):
		utterance = peer[n]
	else:
		utterance = tutor[n]
	send_robot_utterance(utterance)	
	
def start_session(condition):
	send_move_message(4)
	time.sleep(3)
	peer = "Hello, nice to meet you! I am excited to work with you today to create some eletronic circuits. I am sure we will be a great team!"
	tutor = "Hello, nice to meet you! I am excited to teach you today on how to create some eletronic circuits. I am sure you will be a great student!"
	if (condition == "peer"):
		utterance = peer
	else:
		utterance = tutor
	send_robot_utterance(utterance)	
	send_move_message(5)
	
def end_session(condition):
	peer = "Looks like we are finished for today. Thanks so much for building these circuits with me, it was a lot of fun! Shall we call the experimenter back?"
	tutor = "Looks like you are finished for today. Thanks so much for building these circuits for me, it was a lot of fun teaching you! Shall we call the experimenter back?"
	if (condition == "peer"):
		utterance = peer
	else:
		utterance = tutor
	send_robot_utterance(utterance)	

def robot_action(msg):
	print "GOT ROBOT ACTION"
	
	type_action = msg.type_action
	sk = msg.sk
	other = msg.other
	if (type_action == "reinforce_utterance"):
		print "giving reinforcement utterance"
		if (sk == 1): reinforcement_good_1(condition)
		if (sk == 2): reinforcement_good_2(condition)
		if (sk == 3): reinforcement_good_3(condition)
		if (sk == 4): reinforcement_good_4(condition)
		if (sk == 5): reinforcement_good_5(condition)
		if (sk == 6): reinforcement_good_6(condition)
		if (sk == 7): reinforcement_good_7(condition)
		if (sk == 8): reinforcement_good_8(condition)
		if (sk == 9): reinforcement_good_9(condition)
		if (sk == 10): reinforcement_good_10(condition)
		if (sk == 11): reinforcement_good_11(condition)
		if (sk == 12): reinforcement_good_12(condition)
		if (sk == 13): reinforcement_good_13(condition)
		if (sk == 14): reinforcement_good_14(condition)
		if (sk == 15): reinforcement_good_15(condition)
		if (sk == 16): reinforcement_good_16(condition)
		if (sk == 17): reinforcement_good_17(condition)
	if (type_action == "reinforce_question"):
		print "giving reinforcement question"
		if (sk == 1): reinforcement_question_1(condition)
		if (sk == 2): reinforcement_question_2(condition)
		if (sk == 3): reinforcement_question_3(condition)
		if (sk == 4): reinforcement_question_4(condition)
		if (sk == 5): reinforcement_question_5(condition)
		if (sk == 6): reinforcement_question_6(condition)
		if (sk == 7): reinforcement_question_7(condition)
		if (sk == 8): reinforcement_question_8(condition)
		if (sk == 9): reinforcement_question_9(condition)
		if (sk == 10): reinforcement_question_10(condition)
		if (sk == 11): reinforcement_question_11(condition)
		if (sk == 12): reinforcement_question_12(condition)
		if (sk == 13): reinforcement_question_13(condition)
		if (sk == 14): reinforcement_question_14(condition)
		if (sk == 15): reinforcement_question_15(condition)
		if (sk == 16): reinforcement_question_16(condition)
		if (sk == 17): reinforcement_question_17(condition)
	if (type_action == "wrong_piece"):
		print "giving wrong piece utterance"
		name = msg.piece1
		wrongPiece_nopoint(condition,name)
	if (type_action == "wrong_piece_point"):
		print "giving wrong piece point"
		name = msg.piece1
		loc = msg.loc1
		numb = msg.numb1
		wrongPiece_point(condition,name,loc,numb)
	if (type_action == "help"):
		print "giving help utterance"
		if (sk == 1): help_utterance_1(condition)
		if (sk == 2): help_utterance_2(condition)
		if (sk == 3): help_utterance_3(condition)
		if (sk == 4): help_utterance_4(condition)
		if (sk == 5): help_utterance_5(condition)
		if (sk == 6): help_utterance_6(condition)
		if (sk == 7): help_utterance_7(condition)
		if (sk == 8): help_utterance_8(condition)
		if (sk == 9): help_utterance_9(condition)
		if (sk == 10): help_utterance_10(condition)
		if (sk == 11): help_utterance_11(condition)
		if (sk == 12): help_utterance_12(condition)
		if (sk == 13): help_utterance_13(condition)
		if (sk == 14): help_utterance_14(condition)
		if (sk == 15): help_utterance_15(condition)
		if (sk == 16): help_utterance_16(condition)
		if (sk == 17): help_utterance_17(condition)
	if (type_action == "help_move"):
		print "giving help move"
		loc = msg.loc1
		numb = msg.numb1
		if (sk == 1): help_movement_1(condition)
		if (sk == 2): help_movement_2(condition,loc,numb) # letter_led, number_led):
		if (sk == 3): help_movement_3(condition)
		if (sk == 4): help_movement_4(condition)
		if (sk == 5): help_movement_5(condition)
		if (sk == 6): help_movement_6(condition)
		if (sk == 7): help_movement_7(condition)
		if (sk == 8): help_movement_8(condition)
		if (sk == 9): help_movement_9(condition)
		if (sk == 10): help_movement_10(condition,loc,numb) #  p1, l1, n1, p2, l2, n2):
		if (sk == 11): help_movement_11(condition)
		if (sk == 12): help_movement_12(condition,loc,numb) #letter_mc, number_mc):
		if (sk == 13): help_movement_13(condition,loc,numb) #letter_mc, number_mc):
		if (sk == 14): help_movement_14(condition,loc,numb) #letter_mc, number_mc):
		if (sk == 15): help_movement_15(condition,loc,numb) #letter_mc, number_mc):
		if (sk == 16): help_movement_16(condition)
		if (sk == 17): help_movement_17(condition)
		
	if (type_action == "other"):
		print "other robot utterance"
		if (other == 90): start(condition)
		if (other == 91): finished_correct(condition)
		if (other == 92): finished_incorrect(condition)
		if (other == 93): motivation(condition)
		if (other == 94): question_2_pieces(condition)
		if (other == 95): hand_piece(condition)
		if (other == 96): notfinished_incorrect(condition)
		if (other == 97): start_session(condition)
		if (other == 98): end_session(condition)


	
def send_robot_utterance(utterance):
	pubUtterance.publish(utterance)
	rospy.wait_for_service('tts/robot_utterance')
	try:
		grab_piece = rospy.ServiceProxy('tts/robot_utterance', StringSrv)
		response = grab_piece(utterance)
		print response
	except rospy.ServiceException as e:
		print("Service call failed: %s"%e)
	
		
sub = rospy.Subscriber("robot_action_request", RobotActionRequest, robot_action)

if __name__ == "__main__":
	
	currently_moving = 0
	# ~ condition = "peer"
	rospy.init_node("p2p_utterances")
	
	condition = rospy.get_param('~condition')
	print "************"
	print condition
	print "***********"
	
	rospy.spin()
	

# ~ send_robot_utterance("hello, how are you doing?")
# ~ send_robot_utterance("i am doing good and you?")
