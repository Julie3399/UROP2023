# %% [markdown]
# ## Checking whether the circuit is valid
#
# 1. Define a class to store information of electrical components (attributes to be confirmed)
# 2. Link task to electrical componenets
# 3. Path?

# %% [markdown]
# 1. Detect connection (input/output), what is port and waves in connection.py?
# 2. Find all paths (use given function)
# 3. Check (to do)

# %% [markdown]
# ## 1. Define pieces:

# %%
import numpy as np

class Board:
	def __init__(self,name, matrix):
		self.name = name
		self.pos = matrix # the matrix stores class information in each entry
		
class Battery:
	b_id = 1
	def __init__(self, name, x1, x2, y1, y2, inp = [], out = []):
		self.type = "battery"
		#self.width = 3
		#self.height = 3
		self.name = name
		self.inp = []
		self.out = [] 
		self.x1 = x1
		self.x2 = x2
		self.y1 = y1
		self.y2 = y2
		self.power = True
		
	def addInp(self,inp):
		self.inp.append(inp)
	def removeInp(self,inp):
		self.inp.remove(inp)
	def addOut(self,out):
		self.out.append(out)
	def removeOut(self,out):
		self.out.remove(out)
	def setInp(self,inp): # allows assignment
		self.inp = inp
	def setOut(self,out):
		self.out = out

class Wire:
	#TODO - we are not separating each wire, what to do?
	w_id = 1
	
	def __init__(self, name, x1, x2, y1, y2, size, inp = [], out = []):
		self.name = name
		self.type = "wire"
		#self.width = size # between 1 and 7, or 0 for jumper wire
		#self.height = 1
		self.inp = []
		self.out = []
		self.x1 = x1
		self.x2 = x2
		self.y1 = y1
		self.y2 = y2
		self.power = False

	def addInp(self,inp):
		self.inp.append(inp)
	def removeInp(self,inp):
		self.inp.remove(inp)
	def addOut(self,out):
		self.out.append(out)
	def removeOut(self,out):
		self.out.remove(out)
	def setInp(self,inp):
		self.inp = inp
	def setOut(self,out):
		self.out = out

class Switch:
	s_id = 1
	def __init__(self, name, x1, x2, y1, y2, inp = [], out = []):
		self.type = "switch"
		#self.width = 3
		#self.height = 1
		#self.s_type = s_type #press or slide switch
		self.name = name
		self.inp = []
		self.out = []
		self.x1 = x1
		self.x2 = x2
		self.y1 = y1
		self.y2 = y2
		self.power = False
		self.pressed = False
		#self.connected = []
	
	def PressSwitch(self):
		self.pressed = True
		self.outPower = True
	
	def UnpressSwitch(self):
		self.pressed = False
		self.outPower = False
	
	def addInp(self,inp):
		self.inp.append(inp)
	def removeInp(self,inp):
		self.inp.remove(inp)
	def addOut(self,out):
		self.out.append(out)
	def removeOut(self,out):
		self.out.remove(out)
	def setInp(self,inp):
		self.inp = inp
	def setOut(self,out):
		self.out = out
	
class Button:
	b_id = 1
	def __init__(self, name, x1, x2, y1, y2, inp = [], out = []):
		self.type = "button"
		#self.width = 3
		#self.height = 1
		#self.s_type = s_type #press or slide switch
		self.name = name
		self.inp = []
		self.out = []
		self.x1 = x1
		self.x2 = x2
		self.y1 = y1
		self.y2 = y2
		self.power = False
		self.pressed = False
		#self.connected = []
	
	def PressButton(self):
		self.pressed = True
		self.outPower = True
	
	def UnpressButton(self):
		self.pressed = False
		self.outPower = False
	
	def addInp(self,inp):
		self.inp.append(inp)
	def removeInp(self,inp):
		self.inp.remove(inp)
	def addOut(self,out):
		self.out.append(out)
	def removeOut(self,out):
		self.out.remove(out)
	def setInp(self,inp):
		self.inp = inp
	def setOut(self,out):
		self.out = out

class Reed:
    reed_id = 1
    def __init__(self, name, x1, x2, y1, y2, inp=[], out=[]):
        self.type = "reed"
        # self.width = 3
        # self.height = 1
        # self.s_type = s_type #press or slide switch
        self.name = name
        self.inp = []
        self.out = []
        self.x1 = x1
        self.x2 = x2
        self.y1 = y1
        self.y2 = y2
        self.power = False
        self.pressed = False
        # self.connected = []

    def PressReed(self):
        self.pressed = True
        self.outPower = True

    def UnpressReed(self):
        self.pressed = False
        self.outPower = False

    def addInp(self, inp):
        self.inp.append(inp)
    def removeInp(self, inp):
        self.inp.remove(inp)
    def addOut(self, out):
        self.out.append(out)
    def removeOut(self, out):
        self.out.remove(out)
    def setInp(self, inp):
        self.inp = inp
    def setOut(self, out):
        self.out = out


class Led:  # Led that only allows current in one direction
    l_id = 1

    def __init__(self, name, x1, x2, y1, y2, inp=[], out=[]):
        self.type = "led"
        # self.width = 3
        # self.height = 1
        self.name = name
        self.x1 = x1
        self.x2 = x2
        self.y1 = y1
        self.y2 = y2
        self.inp = []
        self.out = []
        self.power = False

    def addInp(self, inp):
        self.inp.append(inp)
    def removeInp(self, inp):
        self.inp.remove(inp)
    def addOut(self, out):
        self.out.append(out)
    def removeOut(self, out):
        self.out.remove(out)
    def setInp(self, inp):
        self.inp = inp
    def setOut(self, out):
        self.out = out

class Lamp:  # Led that only allows current in one direction
    lamp_id = 1

    def __init__(self, name, x1, x2, y1, y2, inp=[], out=[]):
        self.type = "lamp"
        # self.width = 3
        # self.height = 1
        self.name = name
        self.x1 = x1
        self.x2 = x2
        self.y1 = y1
        self.y2 = y2
        self.inp = []
        self.out = []
        self.power = False

    def addInp(self, inp):
        self.inp.append(inp)
    def removeInp(self, inp):
        self.inp.remove(inp)
    def addOut(self, out):
        self.out.append(out)
    def removeOut(self, out):
        self.out.remove(out)
    def setInp(self, inp):
        self.inp = inp
    def setOut(self, out):
        self.out = out

class Speaker:
	sp_id = 1
	def __init__(self, name, x1, x2, y1, y2, inp = [], out = []):
		self.type = "speaker"
		# self.width = 3
		# self.height = 1
		self.name = name
		self.inp = []
		self.out = [] 
		self.x1 = x1
		self.x2 = x2
		self.y1 = y1
		self.y2 = y2
		self.power = False
		
	def addInp(self,inp):
		self.inp.append(inp)
	def removeInp(self,inp):
		self.inp.remove(inp)
	def addOut(self,out):
		self.out.append(out)
	def removeOut(self,out):
		self.out.remove(out)
	def setInp(self,inp):
		self.inp = inp
	def setOut(self,out):
		self.out = out

class Buzzer:
    buz_id = 1
    def __init__(self, name, x1, x2, y1, y2, inp=[], out=[]):
        self.type = "buzzer"
        # self.width = 3
        # self.height = 1
        self.name = name
        self.inp = []
        self.out = []
        self.x1 = x1
        self.x2 = x2
        self.y1 = y1
        self.y2 = y2
        self.power = False

    def addInp(self, inp):
        self.inp.append(inp)
    def removeInp(self, inp):
        self.inp.remove(inp)
    def addOut(self, out):
        self.out.append(out)
    def removeOut(self, out):
        self.out.remove(out)
    def setInp(self, inp):
        self.inp = inp
    def setOut(self, out):
        self.out = out


class Music_Circuit:
    # TO-DO: check trigger? waves?
	mc_id = 1
	def __init__(self, name, x1, x2, y1, y2, inp = [], out = [], trigger = [], waves = [], hold = []): 
		self.type = "mc"
		# self.width = 3
		# self.height = 2
		self.name = name
		self.inp = []
		self.out = [] 
		self.trigger = []
		self.hold = []
		self.waves = []
		self.x1 = x1
		self.x2 = x2
		self.y1 = y1
		self.y2 = y2
		self.power = False
		self.powerInp = False
		self.powerTrigger = False
	
	def addInp(self,inp):
		self.inp.append(inp)
	def removeInp(self,inp):
		self.inp.remove(inp)
	def addHold(self,hold):
		self.hold.append(hold)
	def removeHold(self,hold):
		self.hold.remove(hold)
	def addOut(self,out):
		self.out.append(out)
	def removeOut(self,out):
		self.out.remove(out)
	def addWaves(self,waves):
		self.waves.append(waves)
	def removeWaves(self,waves):
		self.waves.remove(waves)
	def setInp(self,inp):
		self.inp = inp
	def setOut(self,out):
		self.out = out
	def addTrigger(self,trig):
		self.trigger.append(trig)
		self.Power = True
	def removeTrigger(self,trig):
		self.trigger.remove(trig)
	def setPowerTrigger(self,on):
		if on == True:
			self.powerTrigger = True
		else:
			self.powerTrigger = False
		if (self.powerTrigger and self.powerInp):
			self.power = True

	def setPowerInp(self,on):
		if on == True:
			self.powerInp = True
		else:
			self.powerInp = False
		# ~ if (self.powerTrigger and self.powerInp):
			# ~ self.power = True
		if (self.powerInp):
			self.power = True
	def setTrigger(self,trigger):
		self.trigger = trigger
	def setWaves(self,waves):
		self.waves = waves
	def setHold(self,hold):
		self.hold = hold
	def setInp(self,inp):
		self.hold = inp

class FM:
    # TO-DO: check trigger? waves?
	fm_id = 1
	def __init__(self, name, x1, x2, y1, y2, inp = [], out = [], trigger = [], waves = [], hold = []): 
		self.type = "fm"
		# self.width = 3
		# self.height = 2
		self.name = name
		self.inp = []
		self.out = [] 
		self.trigger = []
		self.hold = []
		self.waves = []
		self.x1 = x1
		self.x2 = x2
		self.y1 = y1
		self.y2 = y2
		self.power = False
		self.powerInp = False
		self.powerTrigger = False
	
	def addInp(self,inp):
		self.inp.append(inp)
	def removeInp(self,inp):
		self.inp.remove(inp)
	def addHold(self,hold):
		self.hold.append(hold)
	def removeHold(self,hold):
		self.hold.remove(hold)
	def addOut(self,out):
		self.out.append(out)
	def removeOut(self,out):
		self.out.remove(out)
	def addWaves(self,waves):
		self.waves.append(waves)
	def removeWaves(self,waves):
		self.waves.remove(waves)
	def setInp(self,inp):
		self.inp = inp
	def setOut(self,out):
		self.out = out
	def addTrigger(self,trig):
		self.trigger.append(trig)
		self.Power = True
	def removeTrigger(self,trig):
		self.trigger.remove(trig)
	def setPowerTrigger(self,on):
		if on == True:
			self.powerTrigger = True
		else:
			self.powerTrigger = False
		if (self.powerTrigger and self.powerInp):
			self.power = True

	def setPowerInp(self,on):
		if on == True:
			self.powerInp = True
		else:
			self.powerInp = False
		# ~ if (self.powerTrigger and self.powerInp):
			# ~ self.power = True
		if (self.powerInp):
			self.power = True
	def setTrigger(self,trigger):
		self.trigger = trigger
	def setWaves(self,waves):
		self.waves = waves
	def setHold(self,hold):
		self.hold = hold
	def setInp(self,inp):
		self.hold = inp
	

class Motor:
	m_id = 1
	def __init__(self,name, x1, x2, y1, y2, inp = None, out = None):
		self.type = "motor"
		# self.width = 3
		# self.height = 1
		self.name = name
		self.inp = []
		self.out = [] 
		self.x1 = x1
		self.x2 = x2
		self.y1 = y1
		self.y2 = y2
		self.power = False
		
	def addInp(self,inp):
		self.inp.append(inp)
	def removeInp(self,inp):
		self.inp.remove(inp)
	def addOut(self,out):
		self.out.append(out)
	def removeOut(self,out):
		self.out.remove(out)
	def setInp(self,inp):
		self.inp = inp
	def setOut(self,out):
		self.out = out

##################################################################################

# class Led:
# 	l_id = 1
# 	def __init__(self, name, x1, x2, y1, y2, inp = [], out = []):
# 		self.type = "led"
# 		# self.width = 3
# 		# self.height = 1
# 		self.name = name
# 		self.inp = []
# 		self.out = [] 
# 		self.x1 = x1
# 		self.x2 = x2
# 		self.y1 = y1
# 		self.y2 = y2
# 		self.power = False
# 		self.inp2 = []
		
		
# 	def addInp2(self,inp2):
# 		self.inp2.append(inp2)
# 	def addInp(self,inp):
# 		self.inp.append(inp)
# 	def removeInp(self,inp):
# 		self.inp.remove(inp)
# 	def addOut(self,out):
# 		self.out.append(out)
# 	def removeOut(self,out):
# 		self.out.remove(out)
# 	def setInp(self,inp):
# 		self.inp = inp
# 	def setOut(self,out):
# 		self.out = out

# class Whistle:
# 	def __init__(self, name,start_l, start_n, end_l, end_n, inp = None, out = None):
# 		self.type = "whistle"
# 		self.width = 3
# 		self.height = 1
# 		self.name = name
# 		self.inp = inp
# 		self.out = out 
# 		self.start_l = start_l
# 		self.start_n = start_n
# 		self.end_l = end_l
# 		self.end_n = end_n
# 		self.power = False
	
# 	def setInp(self,inp):
# 		self.inp = inp
# 	def setOut(self,out):
# 		self.out = out
		
# 	def noise():
# 		print ("heard noise")

				
# class Diode: #same as led but only allows current in one direction
# 	#TODO: Need to add that it requires a resistor before it
# 	def __init__(self, name, color, inp = [], out = []):
# 		self.width = 3
# 		self.height = 1
# 		self.name = name
# 		self.color = color
# 		self.inp = []
# 		self.out = [] 
# 		self.power = False
		
# 	def addInp(self,inp):
# 		self.inp.append(inp)
# 	def removeInp(self,inp):
# 		self.inp.remove(inp)
# 	def addOut(self,out):
# 		self.out.append(out)
# 	def removeOut(self,out):
# 		self.out.remove(out)
# 	def setInp(self,inp):
# 		self.inp = inp
# 	def setOut(self,out):
# 		self.out = out
	


# class Photoresistor:
# 	def __init__(self, name, inp = None, out = None):
# 		self.width = 3
# 		self.height = 1
# 		self.name = name
# 		self.inp = inp
# 		self.out = out 
# 		self.power = False
		
# 	def setInp(self,inp):
# 		self.inp = inp
# 	def setOut(self,out):
# 		self.out = out
# 	def lightLevel():
# 		return 0;
		
# class Alarm_Circuit:
# 	def __init__(self, name, inp1 = None, inp2 = None, inp3 = None, out = None, output = None): 
# 		self.width = 3
# 		self.height = 2
# 		self.name = name
# 		self.inp1 = inp1
# 		self.inp2 = inp2
# 		self.inp3 = inp3
# 		self.out = out 
# 		self.output = output
# 		self.power = False
	
# 	def setInp1(self,inp1):
# 		self.inp1 = inp1
# 	def setInp2(self,inp2):
# 		self.inp2 = inp2
# 	def setInp3(self,inp3):
# 		self.inp3 = inp3
# 	def setOutput(self,output):
# 		self.output = output
# 	def setOut(self,out):
# 		self.out = out
		
# class Space_Circuit:
# 	def __init__(self, name, inp = None, inp1 = None, inp2 = None, out = None, output = None): 
# 		self.width = 3
# 		self.height = 2
# 		self.name = name
# 		self.inp1 = inp1
# 		self.inp2 = inp2
# 		self.inp = inp
# 		self.out = out 
# 		self.output = output
# 		self.power = False
		
# 	def setInp1(self,inp1):
# 		self.inp1 = inp1
# 	def setInp2(self,inp2):
# 		self.inp2 = inp2
# 	def setInp(self,inp):
# 		self.inp = inp
# 	def setOutput(self,output):
# 		self.output = output
# 	def setOut(self,out):
# 		self.out = out
	

		
# class Antena_Coil:
# 	def __init__(self, name, inp = None, out = None):
# 		self.width = 3
# 		self.height = 1
# 		self.name = name
# 		self.inp = inp
# 		self.out = out 
# 		self.power = False
		
# 	def setInp(self,inp):
# 		self.inp = inp
# 	def setOut(self,out):
# 		self.out = out
		
# class Microphone:
# 	def __init__(self, name, inp = None, out = None):
# 		self.width = 3
# 		self.height = 1
# 		self.name = name
# 		self.inp = inp
# 		self.out = out
# 		self.power = False 
	
# 	def setInp(self,inp):
# 		self.inp = inp
# 	def setOut(self,out):
# 		self.out = out
		
# class Amplifier: #Need to finish
# 	def __init__(self, name, a_input, output, filtered, inp = None, out = None):
# 		self.width = 3
# 		self.height = 1
# 		self.name = name
# 		self.input = a_input
# 		self.output = output
# 		self.filtered = filtered
# 		self.inp = inp
# 		self.out = out 
# 		self.power = False
		
# 	def setInp(self,inp):
# 		self.inp = inp
# 	def setOut(self,out):
# 		self.out = out

# class Resistor:
# 	r_id = 1
# 	def __init__(self, name,start_l, start_n, end_l, end_n, inp = [], out = []):
# 		self.type = "resistor"
# 		self.width = 3
# 		self.height = 1
# 		self.name = name
# 		# ~ self.amount = amount
# 		self.inp = inp
# 		self.out = out 
# 		self.start_l = start_l
# 		self.start_n = start_n
# 		self.end_l = end_l
# 		self.end_n = end_n
# 		self.power = False
		
# 	def addInp(self,inp):
# 		self.inp.append(inp)
# 	def removeInp(self,inp):
# 		self.inp.remove(inp)
# 	def addOut(self,out):
# 		self.out.append(out)
# 	def removeOut(self,out):
# 		self.out.remove(out)
# 	def setInp(self,inp):
# 		self.inp = inp
# 	def setOut(self,out):
# 		self.out = out


# class Capacitor:
# 	def __init__(self, name, quant, inp = None, out = None):
# 		self.width = 3
# 		self.height = 1
# 		self.name = name
# 		self.quant = quant
# 		self.inp = inp
# 		self.out = out 	
# 		self.power = False
			
# 	def setInp(self,inp):
# 		self.inp = inp
# 	def setOut(self,out):
# 		self.out = out	

# class Integrated_Circuit:
# 	def __init__(self, name,output = None, inp1 = None, inp2 = None, out = None):
# 		self.width = 3
# 		self.height = 2
# 		self.name = name
# 		self.inp1 = inp1
# 		self.inp2 = inp2
# 		self.out = out 	
# 		self.output = output
# 		self.power = False
			
# 	def setInp1(self,inp1):
# 		self.inp1 = inp1
# 	def setInp2(self,inp2):
# 		self.inp2 = inp2
# 	def setOut(self,out):
# 		self.out = out
# 	def setOutput(self,output):
# 		self.output = output

# %% [markdown]
# ## 2. Add Connection

# %%
def add_connection(b,piece,y,x,port):
    """Update the connection of the piece at (x,y)

    Args:
        b (class): an instance of board
        piece (class): an instanc of input piece
        y (float): y coordinate of the input piece
        x (float):  x coordinate of the input piece
        port (str): indication of the type of connection, dual, inp, out, trigger, waves or hold
    """
